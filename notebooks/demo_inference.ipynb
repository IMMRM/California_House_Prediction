# %%
# ----------------------------------
# 1. Import libraries
# ----------------------------------
import requests
import time
import random
import numpy as np
from faker import Faker

# ----------------------------------
# 2. FastAPI endpoint URL
# ----------------------------------
API_URL = "http://127.0.0.1:8000/predict" 

# ----------------------------------
# 3. Initialize Faker
# ----------------------------------
fake = Faker()

# ----------------------------------
# 4. Function to generate fake input as per model schema
# ----------------------------------
def generate_fake_input():
    return {
        "MedInc": round(np.random.uniform(1, 15), 2),         # Median income
        "HouseAge": round(np.random.uniform(1, 50), 2),        # House age
        "Population": int(np.random.uniform(100, 3000)),       # Population
        "Longitude": round(np.random.uniform(-124.35, -114.31), 5),
        "Latitude": round(np.random.uniform(32.54, 41.95), 5)
    }

# ----------------------------------
# 5. Loop to generate and send data
# ----------------------------------
print("🟢 Starting fake data generator. Press STOP to interrupt...\n")

while True:
    try:
        input_data = generate_fake_input()
        response = requests.post(API_URL, json=input_data)

        if response.status_code == 200:
            print(f"✅ Input: {input_data} => Prediction: {response.json()}")
        else:
            print(f"❌ Failed with status {response.status_code}: {response.text}")
        
        time.sleep(5)  # Sleep for 5 seconds

    except KeyboardInterrupt:
        print("\n🛑 Stopped by user.")
        break
    except Exception as e:
        print(f"❗ Error occurred: {e}")
        time.sleep(5)
# Out:
# 🟢 Starting fake data generator. Press STOP to interrupt...
#
# ✅ Input: {'MedInc': 6.49, 'HouseAge': 22.27, 'Population': 512, 'Longitude': -123.91241, 'Latitude': 37.04752} => Prediction: [3.128245340136054, 'prediction:']
# ✅ Input: {'MedInc': 9.76, 'HouseAge': 6.62, 'Population': 2100, 'Longitude': -121.21166, 'Latitude': 33.9414} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 5.23, 'HouseAge': 6.79, 'Population': 879, 'Longitude': -118.27942, 'Latitude': 40.62367} => Prediction: [2.2187636421725228, 'prediction:']
# ✅ Input: {'MedInc': 4.92, 'HouseAge': 3.51, 'Population': 130, 'Longitude': -124.10198, 'Latitude': 34.1208} => Prediction: [2.1754526104770275, 'prediction:']
# ✅ Input: {'MedInc': 5.02, 'HouseAge': 45.86, 'Population': 2011, 'Longitude': -120.03806, 'Latitude': 34.78567} => Prediction: [2.808480453333335, 'prediction:']
# ✅ Input: {'MedInc': 6.89, 'HouseAge': 34.31, 'Population': 1262, 'Longitude': -119.40019, 'Latitude': 34.08378} => Prediction: ['prediction:', 4.471430347826082]
# ✅ Input: {'MedInc': 12.47, 'HouseAge': 45.45, 'Population': 2272, 'Longitude': -122.4994, 'Latitude': 40.22054} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 8.1, 'HouseAge': 25.78, 'Population': 1412, 'Longitude': -114.39709, 'Latitude': 34.55648} => Prediction: [3.972031488095235, 'prediction:']
# ✅ Input: {'MedInc': 2.14, 'HouseAge': 45.38, 'Population': 520, 'Longitude': -120.68436, 'Latitude': 36.08216} => Prediction: [1.052650311220312, 'prediction:']
# ✅ Input: {'MedInc': 1.28, 'HouseAge': 35.92, 'Population': 1217, 'Longitude': -123.6408, 'Latitude': 35.32751} => Prediction: [1.9743985669291344, 'prediction:']
# ✅ Input: {'MedInc': 10.19, 'HouseAge': 47.55, 'Population': 234, 'Longitude': -121.30488, 'Latitude': 36.43766} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 14.2, 'HouseAge': 6.42, 'Population': 585, 'Longitude': -116.44743, 'Latitude': 38.80573} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.83, 'HouseAge': 16.03, 'Population': 1377, 'Longitude': -120.68949, 'Latitude': 37.65274} => Prediction: [3.128245340136054, 'prediction:']
# ✅ Input: {'MedInc': 13.76, 'HouseAge': 43.38, 'Population': 667, 'Longitude': -123.36734, 'Latitude': 40.21672} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 8.27, 'HouseAge': 21.56, 'Population': 417, 'Longitude': -119.64565, 'Latitude': 32.76933} => Prediction: [3.972031488095235, 'prediction:']
# ✅ Input: {'MedInc': 3.54, 'HouseAge': 9.83, 'Population': 2493, 'Longitude': -121.24987, 'Latitude': 40.91676} => Prediction: [1.4442132963988918, 'prediction:']
# ✅ Input: {'MedInc': 12.06, 'HouseAge': 14.76, 'Population': 788, 'Longitude': -117.00718, 'Latitude': 34.05346} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.36, 'HouseAge': 21.45, 'Population': 882, 'Longitude': -117.78326, 'Latitude': 36.25967} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.28, 'HouseAge': 14.92, 'Population': 2611, 'Longitude': -122.83625, 'Latitude': 39.23071} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.65, 'HouseAge': 48.06, 'Population': 741, 'Longitude': -114.61045, 'Latitude': 37.46463} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 3.25, 'HouseAge': 42.92, 'Population': 2816, 'Longitude': -123.44731, 'Latitude': 38.12256} => Prediction: [3.427416132404179, 'prediction:']
# ✅ Input: {'MedInc': 5.76, 'HouseAge': 43.22, 'Population': 1622, 'Longitude': -120.056, 'Latitude': 36.10646} => Prediction: [3.387060593607305, 'prediction:']
# ✅ Input: {'MedInc': 2.68, 'HouseAge': 33.95, 'Population': 938, 'Longitude': -118.85404, 'Latitude': 38.82651} => Prediction: [0.7225785674547985, 'prediction:']
# ✅ Input: {'MedInc': 1.2, 'HouseAge': 17.03, 'Population': 1857, 'Longitude': -115.03846, 'Latitude': 35.04875} => Prediction: [0.7225785674547985, 'prediction:']
# ✅ Input: {'MedInc': 8.79, 'HouseAge': 12.96, 'Population': 2598, 'Longitude': -117.68348, 'Latitude': 35.60763} => Prediction: [3.972031488095235, 'prediction:']
# ✅ Input: {'MedInc': 10.4, 'HouseAge': 2.29, 'Population': 758, 'Longitude': -120.5935, 'Latitude': 38.51175} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.7, 'HouseAge': 6.16, 'Population': 2555, 'Longitude': -117.27891, 'Latitude': 41.23422} => Prediction: [3.128245340136054, 'prediction:']
# ✅ Input: {'MedInc': 6.93, 'HouseAge': 20.98, 'Population': 212, 'Longitude': -120.64784, 'Latitude': 39.01211} => Prediction: [3.37419490291262, 'prediction:']
# ✅ Input: {'MedInc': 9.17, 'HouseAge': 17.21, 'Population': 123, 'Longitude': -123.56995, 'Latitude': 39.54122} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.44, 'HouseAge': 25.1, 'Population': 360, 'Longitude': -120.51283, 'Latitude': 35.37913} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.8, 'HouseAge': 7.5, 'Population': 2732, 'Longitude': -120.18807, 'Latitude': 37.19188} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 3.37, 'HouseAge': 32.88, 'Population': 1612, 'Longitude': -121.7568, 'Latitude': 34.46524} => Prediction: [2.1754526104770275, 'prediction:']
# ✅ Input: {'MedInc': 11.79, 'HouseAge': 44.13, 'Population': 136, 'Longitude': -121.96876, 'Latitude': 39.81281} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.47, 'HouseAge': 9.77, 'Population': 181, 'Longitude': -114.9525, 'Latitude': 38.44634} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.02, 'HouseAge': 19.57, 'Population': 2405, 'Longitude': -118.74958, 'Latitude': 38.22982} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.59, 'HouseAge': 32.82, 'Population': 750, 'Longitude': -119.59907, 'Latitude': 41.30885} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 11.49, 'HouseAge': 36.8, 'Population': 2367, 'Longitude': -117.98973, 'Latitude': 35.5747} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 8.6, 'HouseAge': 40.66, 'Population': 1147, 'Longitude': -120.63876, 'Latitude': 33.66527} => Prediction: ['prediction:', 4.778788739495789]
# ✅ Input: {'MedInc': 1.48, 'HouseAge': 38.44, 'Population': 2809, 'Longitude': -118.79515, 'Latitude': 32.82581} => Prediction: [2.4471441438356174, 'prediction:']
# ✅ Input: {'MedInc': 10.28, 'HouseAge': 13.54, 'Population': 2607, 'Longitude': -116.34012, 'Latitude': 38.06865} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 3.62, 'HouseAge': 46.27, 'Population': 1515, 'Longitude': -120.44687, 'Latitude': 34.91482} => Prediction: [2.125578434414671, 'prediction:']
# ✅ Input: {'MedInc': 4.15, 'HouseAge': 34.33, 'Population': 1691, 'Longitude': -114.59897, 'Latitude': 39.38599} => Prediction: [1.4442132963988918, 'prediction:']
# ✅ Input: {'MedInc': 12.06, 'HouseAge': 7.39, 'Population': 2915, 'Longitude': -121.59616, 'Latitude': 36.5448} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 2.61, 'HouseAge': 20.64, 'Population': 461, 'Longitude': -121.42669, 'Latitude': 34.33845} => Prediction: [2.4471441438356174, 'prediction:']
# ✅ Input: {'MedInc': 10.09, 'HouseAge': 41.19, 'Population': 1644, 'Longitude': -122.50476, 'Latitude': 36.34166} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.16, 'HouseAge': 9.57, 'Population': 475, 'Longitude': -115.87491, 'Latitude': 41.60558} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.4, 'HouseAge': 25.0, 'Population': 365, 'Longitude': -118.01195, 'Latitude': 37.66093} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 4.77, 'HouseAge': 18.47, 'Population': 2742, 'Longitude': -124.30366, 'Latitude': 36.23934} => Prediction: [2.1754526104770275, 'prediction:']
# ✅ Input: {'MedInc': 8.16, 'HouseAge': 11.71, 'Population': 2003, 'Longitude': -118.31989, 'Latitude': 35.17061} => Prediction: [3.972031488095235, 'prediction:']
#
# 🛑 Stopped by user.
