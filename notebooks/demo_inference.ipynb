# %%
# ----------------------------------
# 1. Import libraries
# ----------------------------------
import requests
import time
import random
import numpy as np
from faker import Faker

# ----------------------------------
# 2. FastAPI endpoint URL
# ----------------------------------
API_URL = "http://127.0.0.1:8000/predict" 

# ----------------------------------
# 3. Initialize Faker
# ----------------------------------
fake = Faker()

# ----------------------------------
# 4. Function to generate fake input as per model schema
# ----------------------------------
def generate_fake_input():
    return {
        "MedInc": round(np.random.uniform(1, 15), 2),         # Median income
        "HouseAge": round(np.random.uniform(1, 50), 2),        # House age
        "Population": int(np.random.uniform(100, 3000)),       # Population
        "Longitude": round(np.random.uniform(-124.35, -114.31), 5),
        "Latitude": round(np.random.uniform(32.54, 41.95), 5)
    }

# ----------------------------------
# 5. Loop to generate and send data
# ----------------------------------
print("🟢 Starting fake data generator. Press STOP to interrupt...\n")

while True:
    try:
        input_data = generate_fake_input()
        response = requests.post(API_URL, json=input_data)

        if response.status_code == 200:
            print(f"✅ Input: {input_data} => Prediction: {response.json()}")
        else:
            print(f"❌ Failed with status {response.status_code}: {response.text}")
        
        time.sleep(5)  # Sleep for 5 seconds

    except KeyboardInterrupt:
        print("\n🛑 Stopped by user.")
        break
    except Exception as e:
        print(f"❗ Error occurred: {e}")
        time.sleep(5)
# Out:
# 🟢 Starting fake data generator. Press STOP to interrupt...
#
# ✅ Input: {'MedInc': 5.69, 'HouseAge': 43.86, 'Population': 2015, 'Longitude': -119.33572, 'Latitude': 37.73301} => Prediction: ['prediction:', 3.387060593607306]
# ✅ Input: {'MedInc': 8.01, 'HouseAge': 17.2, 'Population': 1438, 'Longitude': -120.18105, 'Latitude': 33.79069} => Prediction: ['prediction:', 3.9720314880952334]
# ✅ Input: {'MedInc': 13.56, 'HouseAge': 18.31, 'Population': 268, 'Longitude': -115.93173, 'Latitude': 32.67815} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 9.56, 'HouseAge': 14.41, 'Population': 1749, 'Longitude': -118.56192, 'Latitude': 37.01931} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 6.03, 'HouseAge': 30.98, 'Population': 1343, 'Longitude': -117.92029, 'Latitude': 36.30112} => Prediction: ['prediction:', 3.64033939849624]
# ✅ Input: {'MedInc': 4.18, 'HouseAge': 43.75, 'Population': 1888, 'Longitude': -116.77673, 'Latitude': 38.82378} => Prediction: ['prediction:', 2.8084804533333334]
# ✅ Input: {'MedInc': 3.64, 'HouseAge': 21.12, 'Population': 2565, 'Longitude': -122.46978, 'Latitude': 34.47798} => Prediction: ['prediction:', 2.1754526104770275]
# ✅ Input: {'MedInc': 3.03, 'HouseAge': 5.88, 'Population': 1165, 'Longitude': -119.94983, 'Latitude': 36.82155} => Prediction: ['prediction:', 1.0526503112203114]
# ✅ Input: {'MedInc': 13.43, 'HouseAge': 29.75, 'Population': 2233, 'Longitude': -121.32979, 'Latitude': 36.51034} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 1.29, 'HouseAge': 10.23, 'Population': 1504, 'Longitude': -116.51788, 'Latitude': 35.60124} => Prediction: [0.7225785674547989, 'prediction:']
# ✅ Input: {'MedInc': 7.55, 'HouseAge': 38.75, 'Population': 1206, 'Longitude': -121.38414, 'Latitude': 32.64015} => Prediction: ['prediction:', 4.471430347826082]
# ✅ Input: {'MedInc': 13.77, 'HouseAge': 21.65, 'Population': 716, 'Longitude': -121.5024, 'Latitude': 37.03201} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 5.63, 'HouseAge': 15.53, 'Population': 1353, 'Longitude': -114.81171, 'Latitude': 40.77705} => Prediction: ['prediction:', 2.2187636421725236]
# ✅ Input: {'MedInc': 5.05, 'HouseAge': 49.34, 'Population': 438, 'Longitude': -118.46061, 'Latitude': 38.61098} => Prediction: ['prediction:', 2.8084804533333334]
# ✅ Input: {'MedInc': 11.81, 'HouseAge': 49.19, 'Population': 2107, 'Longitude': -120.81307, 'Latitude': 38.84819} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 6.46, 'HouseAge': 39.23, 'Population': 2978, 'Longitude': -121.34123, 'Latitude': 39.17456} => Prediction: ['prediction:', 3.64033939849624]
# ✅ Input: {'MedInc': 6.96, 'HouseAge': 22.61, 'Population': 1465, 'Longitude': -124.21567, 'Latitude': 39.10474} => Prediction: ['prediction:', 3.8872518181818183]
# ✅ Input: {'MedInc': 2.1, 'HouseAge': 40.91, 'Population': 2028, 'Longitude': -124.24175, 'Latitude': 38.83564} => Prediction: ['prediction:', 1.0612313134328362]
# ✅ Input: {'MedInc': 7.15, 'HouseAge': 26.23, 'Population': 137, 'Longitude': -118.51149, 'Latitude': 39.76602} => Prediction: ['prediction:', 3.3741949029126186]
# ✅ Input: {'MedInc': 3.45, 'HouseAge': 24.11, 'Population': 1078, 'Longitude': -118.1222, 'Latitude': 33.44907} => Prediction: ['prediction:', 2.1754526104770275]
# ✅ Input: {'MedInc': 12.78, 'HouseAge': 29.69, 'Population': 629, 'Longitude': -123.95891, 'Latitude': 40.97708} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 13.69, 'HouseAge': 39.25, 'Population': 2057, 'Longitude': -123.38409, 'Latitude': 37.93177} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 7.47, 'HouseAge': 4.27, 'Population': 1441, 'Longitude': -116.98675, 'Latitude': 34.86364} => Prediction: ['prediction:', 3.3741949029126186]
# ✅ Input: {'MedInc': 14.1, 'HouseAge': 35.74, 'Population': 1215, 'Longitude': -122.41136, 'Latitude': 41.31607} => Prediction: ['prediction:', 4.860650727272709]
# ✅ Input: {'MedInc': 8.22, 'HouseAge': 28.3, 'Population': 499, 'Longitude': -116.82453, 'Latitude': 33.99812} => Prediction: ['prediction:', 3.9720314880952334]
# ✅ Input: {'MedInc': 12.11, 'HouseAge': 3.58, 'Population': 174, 'Longitude': -119.087, 'Latitude': 41.5566} => Prediction: ['prediction:', 4.860650727272709]
#
# 🛑 Stopped by user.
