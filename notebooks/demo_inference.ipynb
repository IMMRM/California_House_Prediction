# %%
# ----------------------------------
# 1. Import libraries
# ----------------------------------
import requests
import time
import random
import numpy as np
from faker import Faker

# ----------------------------------
# 2. FastAPI endpoint URL
# ----------------------------------
API_URL = "http://127.0.0.1:8000/predict" 

# ----------------------------------
# 3. Initialize Faker
# ----------------------------------
fake = Faker()

# ----------------------------------
# 4. Function to generate fake input as per model schema
# ----------------------------------
def generate_fake_input():
    return {
        "MedInc": round(np.random.uniform(1, 15), 2),         # Median income
        "HouseAge": round(np.random.uniform(1, 50), 2),        # House age
        "Population": int(np.random.uniform(100, 3000)),       # Population
        "Longitude": round(np.random.uniform(-124.35, -114.31), 5),
        "Latitude": round(np.random.uniform(32.54, 41.95), 5)
    }

# ----------------------------------
# 5. Loop to generate and send data
# ----------------------------------
print("🟢 Starting fake data generator. Press STOP to interrupt...\n")

while True:
    try:
        input_data = generate_fake_input()
        response = requests.post(API_URL, json=input_data)

        if response.status_code == 200:
            print(f"✅ Input: {input_data} => Prediction: {response.json()}")
        else:
            print(f"❌ Failed with status {response.status_code}: {response.text}")
        
        time.sleep(5)  # Sleep for 5 seconds

    except KeyboardInterrupt:
        print("\n🛑 Stopped by user.")
        break
    except Exception as e:
        print(f"❗ Error occurred: {e}")
        time.sleep(5)
# Out:
# 🟢 Starting fake data generator. Press STOP to interrupt...
#
# ✅ Input: {'MedInc': 13.98, 'HouseAge': 46.07, 'Population': 2549, 'Longitude': -114.64114, 'Latitude': 35.70972} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.76, 'HouseAge': 16.39, 'Population': 2532, 'Longitude': -116.2911, 'Latitude': 37.58557} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.05, 'HouseAge': 30.54, 'Population': 1967, 'Longitude': -119.1524, 'Latitude': 33.13704} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 14.89, 'HouseAge': 46.03, 'Population': 279, 'Longitude': -118.36519, 'Latitude': 37.22988} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.31, 'HouseAge': 29.74, 'Population': 479, 'Longitude': -120.9557, 'Latitude': 35.34953} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 10.71, 'HouseAge': 9.34, 'Population': 2311, 'Longitude': -115.35527, 'Latitude': 37.22712} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.92, 'HouseAge': 10.41, 'Population': 2599, 'Longitude': -118.34999, 'Latitude': 41.71472} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 11.49, 'HouseAge': 24.08, 'Population': 2951, 'Longitude': -123.48048, 'Latitude': 35.77458} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 11.58, 'HouseAge': 30.4, 'Population': 2103, 'Longitude': -120.63321, 'Latitude': 40.24232} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 2.05, 'HouseAge': 39.03, 'Population': 2098, 'Longitude': -115.66539, 'Latitude': 35.18765} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 1.71, 'HouseAge': 12.51, 'Population': 1106, 'Longitude': -120.82389, 'Latitude': 41.7765} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 10.08, 'HouseAge': 49.65, 'Population': 1975, 'Longitude': -116.62539, 'Latitude': 36.35226} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 7.42, 'HouseAge': 43.74, 'Population': 1480, 'Longitude': -119.88705, 'Latitude': 36.48696} => Prediction: ['prediction:', 4.471430347826082]
# ✅ Input: {'MedInc': 3.78, 'HouseAge': 14.12, 'Population': 978, 'Longitude': -116.38078, 'Latitude': 38.38967} => Prediction: ['prediction:', 1.444213296398893]
# ✅ Input: {'MedInc': 10.33, 'HouseAge': 16.76, 'Population': 676, 'Longitude': -124.18755, 'Latitude': 34.34031} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 8.25, 'HouseAge': 31.26, 'Population': 781, 'Longitude': -119.8225, 'Latitude': 36.58794} => Prediction: ['prediction:', 4.77878873949579]
# ✅ Input: {'MedInc': 1.86, 'HouseAge': 9.61, 'Population': 2594, 'Longitude': -121.2471, 'Latitude': 39.31292} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 14.73, 'HouseAge': 41.46, 'Population': 1973, 'Longitude': -118.63871, 'Latitude': 34.35272} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.5, 'HouseAge': 38.35, 'Population': 2952, 'Longitude': -122.67313, 'Latitude': 38.82997} => Prediction: ['prediction:', 1.0612313134328355]
# ✅ Input: {'MedInc': 4.59, 'HouseAge': 10.05, 'Population': 996, 'Longitude': -123.69201, 'Latitude': 38.99765} => Prediction: ['prediction:', 1.9564824561403495]
# ✅ Input: {'MedInc': 14.25, 'HouseAge': 19.99, 'Population': 1250, 'Longitude': -123.60448, 'Latitude': 39.76027} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.57, 'HouseAge': 32.79, 'Population': 1845, 'Longitude': -121.57633, 'Latitude': 36.53566} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.67, 'HouseAge': 26.18, 'Population': 987, 'Longitude': -115.981, 'Latitude': 32.81666} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 7.42, 'HouseAge': 20.32, 'Population': 2233, 'Longitude': -119.45932, 'Latitude': 35.72731} => Prediction: ['prediction:', 3.37419490291262]
# ✅ Input: {'MedInc': 6.79, 'HouseAge': 24.47, 'Population': 306, 'Longitude': -122.50441, 'Latitude': 39.55045} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 11.13, 'HouseAge': 9.06, 'Population': 517, 'Longitude': -119.64798, 'Latitude': 35.72014} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.81, 'HouseAge': 12.51, 'Population': 489, 'Longitude': -118.29246, 'Latitude': 37.36208} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.09, 'HouseAge': 2.57, 'Population': 1001, 'Longitude': -119.31128, 'Latitude': 41.53633} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.61, 'HouseAge': 15.17, 'Population': 2161, 'Longitude': -121.61911, 'Latitude': 37.31543} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 6.84, 'HouseAge': 27.86, 'Population': 607, 'Longitude': -118.45738, 'Latitude': 39.42433} => Prediction: ['prediction:', 3.6403393984962404]
# ✅ Input: {'MedInc': 4.45, 'HouseAge': 17.76, 'Population': 1644, 'Longitude': -114.61686, 'Latitude': 34.19673} => Prediction: ['prediction:', 1.6563471763602262]
# ✅ Input: {'MedInc': 4.4, 'HouseAge': 12.81, 'Population': 1613, 'Longitude': -122.03637, 'Latitude': 34.79656} => Prediction: ['prediction:', 2.1754526104770284]
# ✅ Input: {'MedInc': 7.93, 'HouseAge': 38.59, 'Population': 2165, 'Longitude': -122.81899, 'Latitude': 36.13725} => Prediction: ['prediction:', 4.77878873949579]
# ✅ Input: {'MedInc': 11.72, 'HouseAge': 26.36, 'Population': 2201, 'Longitude': -117.23534, 'Latitude': 38.35791} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 4.74, 'HouseAge': 49.58, 'Population': 897, 'Longitude': -120.30462, 'Latitude': 36.43188} => Prediction: ['prediction:', 2.808480453333335]
# ✅ Input: {'MedInc': 4.13, 'HouseAge': 46.63, 'Population': 479, 'Longitude': -123.72834, 'Latitude': 38.2969} => Prediction: ['prediction:', 1.6978620689655173]
# ✅ Input: {'MedInc': 13.86, 'HouseAge': 7.88, 'Population': 1219, 'Longitude': -115.16736, 'Latitude': 37.86895} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 4.09, 'HouseAge': 28.78, 'Population': 2014, 'Longitude': -115.01401, 'Latitude': 37.52647} => Prediction: ['prediction:', 1.6563471763602262]
# ✅ Input: {'MedInc': 12.24, 'HouseAge': 40.76, 'Population': 1187, 'Longitude': -123.6675, 'Latitude': 33.68581} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.35, 'HouseAge': 12.41, 'Population': 2820, 'Longitude': -114.93452, 'Latitude': 34.86262} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 7.92, 'HouseAge': 22.91, 'Population': 2003, 'Longitude': -120.10126, 'Latitude': 32.86135} => Prediction: ['prediction:', 3.9720314880952348]
# ✅ Input: {'MedInc': 7.5, 'HouseAge': 6.63, 'Population': 2488, 'Longitude': -115.41554, 'Latitude': 38.93475} => Prediction: ['prediction:', 3.37419490291262]
# ✅ Input: {'MedInc': 4.05, 'HouseAge': 5.08, 'Population': 1497, 'Longitude': -118.36579, 'Latitude': 33.30857} => Prediction: ['prediction:', 2.1754526104770284]
# ✅ Input: {'MedInc': 13.52, 'HouseAge': 47.4, 'Population': 1674, 'Longitude': -118.01756, 'Latitude': 34.80894} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 11.52, 'HouseAge': 4.76, 'Population': 2529, 'Longitude': -118.77244, 'Latitude': 39.55163} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 7.6, 'HouseAge': 43.2, 'Population': 1101, 'Longitude': -117.19512, 'Latitude': 38.33707} => Prediction: ['prediction:', 3.6397148571428577]
# ✅ Input: {'MedInc': 11.23, 'HouseAge': 12.72, 'Population': 2209, 'Longitude': -118.85529, 'Latitude': 35.81374} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 2.19, 'HouseAge': 2.77, 'Population': 1053, 'Longitude': -122.23974, 'Latitude': 37.75175} => Prediction: ['prediction:', 1.9743985669291335]
# ✅ Input: {'MedInc': 5.83, 'HouseAge': 47.84, 'Population': 1208, 'Longitude': -117.73285, 'Latitude': 39.43499} => Prediction: ['prediction:', 3.387060593607305]
# ✅ Input: {'MedInc': 5.44, 'HouseAge': 42.31, 'Population': 510, 'Longitude': -120.47058, 'Latitude': 34.95063} => Prediction: ['prediction:', 3.387060593607305]
# ✅ Input: {'MedInc': 6.48, 'HouseAge': 23.72, 'Population': 291, 'Longitude': -122.12677, 'Latitude': 40.43258} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 2.38, 'HouseAge': 27.69, 'Population': 1594, 'Longitude': -118.83083, 'Latitude': 38.6779} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 2.24, 'HouseAge': 37.09, 'Population': 667, 'Longitude': -118.33244, 'Latitude': 41.47921} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 7.92, 'HouseAge': 33.63, 'Population': 637, 'Longitude': -115.3662, 'Latitude': 33.27917} => Prediction: ['prediction:', 4.77878873949579]
# ✅ Input: {'MedInc': 6.69, 'HouseAge': 5.62, 'Population': 1275, 'Longitude': -121.35938, 'Latitude': 32.90209} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 9.57, 'HouseAge': 6.13, 'Population': 523, 'Longitude': -122.60989, 'Latitude': 40.58181} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.78, 'HouseAge': 26.16, 'Population': 1572, 'Longitude': -121.79937, 'Latitude': 39.47324} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.49, 'HouseAge': 7.87, 'Population': 1416, 'Longitude': -116.14059, 'Latitude': 40.78424} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 14.45, 'HouseAge': 16.88, 'Population': 2027, 'Longitude': -115.94459, 'Latitude': 34.02709} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 7.02, 'HouseAge': 40.42, 'Population': 212, 'Longitude': -121.17865, 'Latitude': 38.04397} => Prediction: ['prediction:', 3.6397148571428577]
# ✅ Input: {'MedInc': 14.45, 'HouseAge': 37.73, 'Population': 398, 'Longitude': -115.53064, 'Latitude': 33.19095} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.34, 'HouseAge': 17.42, 'Population': 2838, 'Longitude': -122.70603, 'Latitude': 40.44777} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 1.9, 'HouseAge': 31.91, 'Population': 2524, 'Longitude': -121.03586, 'Latitude': 34.74073} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 13.18, 'HouseAge': 44.14, 'Population': 855, 'Longitude': -115.42655, 'Latitude': 41.64254} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.14, 'HouseAge': 1.91, 'Population': 1150, 'Longitude': -118.21729, 'Latitude': 36.71244} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.82, 'HouseAge': 27.64, 'Population': 503, 'Longitude': -117.279, 'Latitude': 41.19555} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 14.87, 'HouseAge': 44.93, 'Population': 675, 'Longitude': -123.00875, 'Latitude': 35.97788} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 4.53, 'HouseAge': 13.2, 'Population': 583, 'Longitude': -118.42546, 'Latitude': 41.02297} => Prediction: ['prediction:', 1.444213296398893]
# ✅ Input: {'MedInc': 10.27, 'HouseAge': 3.46, 'Population': 270, 'Longitude': -121.68369, 'Latitude': 35.73149} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.9, 'HouseAge': 30.0, 'Population': 496, 'Longitude': -115.42721, 'Latitude': 36.70351} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.61, 'HouseAge': 13.89, 'Population': 1360, 'Longitude': -119.99429, 'Latitude': 41.49175} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 14.04, 'HouseAge': 40.32, 'Population': 1569, 'Longitude': -114.73914, 'Latitude': 35.62507} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.59, 'HouseAge': 48.83, 'Population': 575, 'Longitude': -114.56638, 'Latitude': 34.77882} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 13.32, 'HouseAge': 47.94, 'Population': 2548, 'Longitude': -118.11671, 'Latitude': 34.81315} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.48, 'HouseAge': 32.99, 'Population': 1787, 'Longitude': -115.92548, 'Latitude': 38.77416} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 8.98, 'HouseAge': 44.27, 'Population': 1209, 'Longitude': -122.37063, 'Latitude': 33.04974} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 5.18, 'HouseAge': 34.6, 'Population': 2133, 'Longitude': -123.16457, 'Latitude': 40.15008} => Prediction: ['prediction:', 2.8261251523545696]
# ✅ Input: {'MedInc': 14.69, 'HouseAge': 26.57, 'Population': 280, 'Longitude': -123.11592, 'Latitude': 40.62889} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 2.96, 'HouseAge': 4.06, 'Population': 985, 'Longitude': -119.4443, 'Latitude': 38.54801} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 10.72, 'HouseAge': 48.24, 'Population': 874, 'Longitude': -119.60858, 'Latitude': 40.84484} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.38, 'HouseAge': 4.87, 'Population': 2914, 'Longitude': -120.08912, 'Latitude': 36.95291} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 2.28, 'HouseAge': 10.85, 'Population': 2302, 'Longitude': -119.90995, 'Latitude': 37.97858} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 7.46, 'HouseAge': 31.03, 'Population': 2228, 'Longitude': -124.16119, 'Latitude': 38.63213} => Prediction: ['prediction:', 3.6397148571428577]
# ✅ Input: {'MedInc': 2.55, 'HouseAge': 29.41, 'Population': 1781, 'Longitude': -123.84761, 'Latitude': 37.64474} => Prediction: ['prediction:', 1.9743985669291335]
# ✅ Input: {'MedInc': 11.96, 'HouseAge': 39.57, 'Population': 1603, 'Longitude': -118.62265, 'Latitude': 36.38726} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.74, 'HouseAge': 7.32, 'Population': 1106, 'Longitude': -124.24422, 'Latitude': 36.08305} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.35, 'HouseAge': 6.63, 'Population': 631, 'Longitude': -123.7074, 'Latitude': 35.76992} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 14.22, 'HouseAge': 33.0, 'Population': 873, 'Longitude': -121.00361, 'Latitude': 41.81166} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.48, 'HouseAge': 38.5, 'Population': 1088, 'Longitude': -122.3008, 'Latitude': 40.78008} => Prediction: ['prediction:', 1.0612313134328355]
# ✅ Input: {'MedInc': 4.92, 'HouseAge': 45.22, 'Population': 2487, 'Longitude': -123.95346, 'Latitude': 38.96678} => Prediction: ['prediction:', 1.6978620689655173]
# ✅ Input: {'MedInc': 11.41, 'HouseAge': 12.33, 'Population': 749, 'Longitude': -116.05472, 'Latitude': 40.63985} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.61, 'HouseAge': 45.99, 'Population': 2147, 'Longitude': -119.78887, 'Latitude': 37.47817} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.27, 'HouseAge': 43.98, 'Population': 537, 'Longitude': -118.563, 'Latitude': 33.86711} => Prediction: ['prediction:', 2.4471441438356156]
# ✅ Input: {'MedInc': 5.15, 'HouseAge': 21.06, 'Population': 1437, 'Longitude': -117.78576, 'Latitude': 34.31832} => Prediction: ['prediction:', 2.6117145238095225]
# ✅ Input: {'MedInc': 11.9, 'HouseAge': 11.0, 'Population': 2009, 'Longitude': -116.89985, 'Latitude': 36.123} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.37, 'HouseAge': 31.74, 'Population': 864, 'Longitude': -122.01275, 'Latitude': 34.04633} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.46, 'HouseAge': 14.19, 'Population': 1070, 'Longitude': -122.40195, 'Latitude': 34.84873} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.71, 'HouseAge': 4.54, 'Population': 411, 'Longitude': -115.4808, 'Latitude': 41.6944} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 12.61, 'HouseAge': 19.99, 'Population': 1906, 'Longitude': -115.64329, 'Latitude': 41.27369} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.03, 'HouseAge': 24.78, 'Population': 1696, 'Longitude': -117.07657, 'Latitude': 35.53897} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 8.38, 'HouseAge': 22.4, 'Population': 2807, 'Longitude': -119.24542, 'Latitude': 32.67931} => Prediction: ['prediction:', 3.9720314880952348]
# ✅ Input: {'MedInc': 14.74, 'HouseAge': 33.79, 'Population': 674, 'Longitude': -118.91162, 'Latitude': 40.61451} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.27, 'HouseAge': 9.18, 'Population': 2023, 'Longitude': -120.36963, 'Latitude': 37.8546} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 10.3, 'HouseAge': 37.4, 'Population': 931, 'Longitude': -121.07921, 'Latitude': 33.52295} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.45, 'HouseAge': 34.59, 'Population': 2704, 'Longitude': -120.40422, 'Latitude': 41.43976} => Prediction: ['prediction:', 1.0526503112203098]
# ✅ Input: {'MedInc': 9.85, 'HouseAge': 29.29, 'Population': 2993, 'Longitude': -119.71209, 'Latitude': 41.28338} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.63, 'HouseAge': 11.15, 'Population': 1178, 'Longitude': -115.72986, 'Latitude': 33.12742} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.9, 'HouseAge': 14.87, 'Population': 2502, 'Longitude': -119.74915, 'Latitude': 40.31499} => Prediction: ['prediction:', 3.37419490291262]
# ✅ Input: {'MedInc': 13.8, 'HouseAge': 34.9, 'Population': 1906, 'Longitude': -122.42334, 'Latitude': 32.97071} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.48, 'HouseAge': 7.77, 'Population': 1058, 'Longitude': -122.87616, 'Latitude': 35.64919} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 7.27, 'HouseAge': 15.24, 'Population': 1444, 'Longitude': -116.28971, 'Latitude': 38.93929} => Prediction: ['prediction:', 3.37419490291262]
# ✅ Input: {'MedInc': 4.23, 'HouseAge': 48.73, 'Population': 1516, 'Longitude': -114.32304, 'Latitude': 34.55668} => Prediction: ['prediction:', 2.808480453333335]
# ✅ Input: {'MedInc': 5.52, 'HouseAge': 35.84, 'Population': 2780, 'Longitude': -122.95901, 'Latitude': 37.86319} => Prediction: ['prediction:', 2.8261251523545696]
# ✅ Input: {'MedInc': 5.75, 'HouseAge': 7.05, 'Population': 1741, 'Longitude': -120.5071, 'Latitude': 39.13516} => Prediction: ['prediction:', 2.7965691666666666]
# ✅ Input: {'MedInc': 12.98, 'HouseAge': 48.17, 'Population': 2862, 'Longitude': -122.58506, 'Latitude': 39.59028} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 5.24, 'HouseAge': 10.9, 'Population': 2245, 'Longitude': -120.81648, 'Latitude': 35.33917} => Prediction: ['prediction:', 2.218763642172524]
# ✅ Input: {'MedInc': 8.18, 'HouseAge': 49.48, 'Population': 864, 'Longitude': -122.90668, 'Latitude': 37.09808} => Prediction: ['prediction:', 4.77878873949579]
# ✅ Input: {'MedInc': 9.72, 'HouseAge': 9.07, 'Population': 2052, 'Longitude': -117.15488, 'Latitude': 38.58138} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 4.22, 'HouseAge': 44.76, 'Population': 1829, 'Longitude': -122.0115, 'Latitude': 37.89443} => Prediction: ['prediction:', 2.808480453333335]
# ✅ Input: {'MedInc': 6.75, 'HouseAge': 40.99, 'Population': 1673, 'Longitude': -123.38567, 'Latitude': 39.25073} => Prediction: ['prediction:', 4.150307478260865]
# ✅ Input: {'MedInc': 8.73, 'HouseAge': 9.65, 'Population': 1145, 'Longitude': -115.10096, 'Latitude': 40.63017} => Prediction: ['prediction:', 3.9720314880952348]
# ✅ Input: {'MedInc': 7.1, 'HouseAge': 39.63, 'Population': 1618, 'Longitude': -123.81824, 'Latitude': 36.68531} => Prediction: ['prediction:', 4.471430347826082]
# ✅ Input: {'MedInc': 11.07, 'HouseAge': 27.48, 'Population': 1908, 'Longitude': -115.03132, 'Latitude': 35.05056} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 14.74, 'HouseAge': 46.63, 'Population': 2095, 'Longitude': -120.75957, 'Latitude': 40.33497} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.37, 'HouseAge': 14.34, 'Population': 1580, 'Longitude': -115.85853, 'Latitude': 36.50352} => Prediction: ['prediction:', 3.128245340136054]
# ✅ Input: {'MedInc': 14.03, 'HouseAge': 5.37, 'Population': 1456, 'Longitude': -120.00228, 'Latitude': 32.55775} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 1.54, 'HouseAge': 6.25, 'Population': 729, 'Longitude': -116.97038, 'Latitude': 40.44723} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 4.09, 'HouseAge': 7.33, 'Population': 2454, 'Longitude': -121.70734, 'Latitude': 33.61617} => Prediction: ['prediction:', 2.1754526104770284]
# ✅ Input: {'MedInc': 5.49, 'HouseAge': 38.78, 'Population': 1625, 'Longitude': -124.27771, 'Latitude': 40.28507} => Prediction: ['prediction:', 3.387060593607305]
# ✅ Input: {'MedInc': 2.25, 'HouseAge': 2.42, 'Population': 271, 'Longitude': -119.16906, 'Latitude': 36.08528} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 13.57, 'HouseAge': 49.45, 'Population': 434, 'Longitude': -119.4842, 'Latitude': 41.8604} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 3.37, 'HouseAge': 7.16, 'Population': 2080, 'Longitude': -123.90046, 'Latitude': 39.30719} => Prediction: ['prediction:', 1.9564824561403495]
# ✅ Input: {'MedInc': 13.31, 'HouseAge': 40.36, 'Population': 1590, 'Longitude': -116.22665, 'Latitude': 32.90529} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 11.65, 'HouseAge': 46.12, 'Population': 1750, 'Longitude': -115.71337, 'Latitude': 35.83683} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 2.97, 'HouseAge': 5.85, 'Population': 1786, 'Longitude': -117.78828, 'Latitude': 40.00357} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 6.59, 'HouseAge': 42.04, 'Population': 215, 'Longitude': -121.46383, 'Latitude': 34.94977} => Prediction: ['prediction:', 4.150307478260865]
# ✅ Input: {'MedInc': 9.52, 'HouseAge': 37.07, 'Population': 217, 'Longitude': -118.54801, 'Latitude': 39.78364} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 3.96, 'HouseAge': 35.5, 'Population': 1365, 'Longitude': -120.53893, 'Latitude': 37.0159} => Prediction: ['prediction:', 2.1754526104770284]
# ✅ Input: {'MedInc': 4.42, 'HouseAge': 24.67, 'Population': 853, 'Longitude': -118.33599, 'Latitude': 34.42883} => Prediction: ['prediction:', 2.1754526104770284]
# ✅ Input: {'MedInc': 1.06, 'HouseAge': 8.01, 'Population': 2600, 'Longitude': -123.23959, 'Latitude': 39.70011} => Prediction: ['prediction:', 1.0612313134328355]
# ✅ Input: {'MedInc': 2.56, 'HouseAge': 29.21, 'Population': 1404, 'Longitude': -118.26419, 'Latitude': 34.60126} => Prediction: [0.7225785674547986, 'prediction:']
# ✅ Input: {'MedInc': 10.48, 'HouseAge': 23.76, 'Population': 1109, 'Longitude': -114.38738, 'Latitude': 36.15643} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 12.9, 'HouseAge': 19.88, 'Population': 2081, 'Longitude': -118.7046, 'Latitude': 35.8995} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 3.84, 'HouseAge': 41.76, 'Population': 2446, 'Longitude': -118.75132, 'Latitude': 37.36679} => Prediction: ['prediction:', 2.125578434414671]
# ✅ Input: {'MedInc': 5.13, 'HouseAge': 4.05, 'Population': 641, 'Longitude': -116.91271, 'Latitude': 33.11908} => Prediction: ['prediction:', 2.218763642172524]
# ✅ Input: {'MedInc': 8.97, 'HouseAge': 27.23, 'Population': 1482, 'Longitude': -122.38836, 'Latitude': 35.8969} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.87, 'HouseAge': 28.9, 'Population': 1949, 'Longitude': -114.35231, 'Latitude': 34.33945} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 6.26, 'HouseAge': 45.35, 'Population': 1013, 'Longitude': -122.01875, 'Latitude': 36.52306} => Prediction: ['prediction:', 4.150307478260865]
# ✅ Input: {'MedInc': 4.48, 'HouseAge': 44.17, 'Population': 1138, 'Longitude': -121.60402, 'Latitude': 36.10836} => Prediction: ['prediction:', 2.808480453333335]
# ✅ Input: {'MedInc': 7.44, 'HouseAge': 9.91, 'Population': 520, 'Longitude': -116.77318, 'Latitude': 32.87299} => Prediction: ['prediction:', 3.37419490291262]
# ✅ Input: {'MedInc': 10.72, 'HouseAge': 5.92, 'Population': 512, 'Longitude': -116.78395, 'Latitude': 35.59102} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 4.85, 'HouseAge': 24.36, 'Population': 2242, 'Longitude': -121.39422, 'Latitude': 35.70245} => Prediction: ['prediction:', 2.1754526104770284]
# ✅ Input: {'MedInc': 6.19, 'HouseAge': 45.47, 'Population': 1617, 'Longitude': -121.46571, 'Latitude': 38.38628} => Prediction: ['prediction:', 4.150307478260865]
# ✅ Input: {'MedInc': 3.39, 'HouseAge': 38.38, 'Population': 913, 'Longitude': -115.27819, 'Latitude': 36.15693} => Prediction: ['prediction:', 1.6563471763602262]
# ✅ Input: {'MedInc': 11.46, 'HouseAge': 3.65, 'Population': 807, 'Longitude': -116.92704, 'Latitude': 34.5305} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 9.86, 'HouseAge': 31.77, 'Population': 2434, 'Longitude': -120.52594, 'Latitude': 39.06376} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 11.17, 'HouseAge': 49.98, 'Population': 227, 'Longitude': -117.75167, 'Latitude': 40.58274} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.14, 'HouseAge': 44.14, 'Population': 775, 'Longitude': -116.45807, 'Latitude': 38.92174} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 10.33, 'HouseAge': 43.18, 'Population': 2473, 'Longitude': -121.52349, 'Latitude': 41.39539} => Prediction: ['prediction:', 4.860650727272711]
# ✅ Input: {'MedInc': 13.51, 'HouseAge': 15.8, 'Population': 2345, 'Longitude': -119.64302, 'Latitude': 37.35136} => Prediction: ['prediction:', 4.860650727272711]
#
# 🛑 Stopped by user.
