# %%
# ----------------------------------
# 1. Import libraries
# ----------------------------------
import requests
import time
import random
import numpy as np
from faker import Faker

# ----------------------------------
# 2. FastAPI endpoint URL
# ----------------------------------
API_URL = "http://127.0.0.1:8000/predict" 

# ----------------------------------
# 3. Initialize Faker
# ----------------------------------
fake = Faker()

# ----------------------------------
# 4. Function to generate fake input as per model schema
# ----------------------------------
def generate_fake_input():
    return {
        "MedInc": round(np.random.uniform(1, 15), 2),         # Median income
        "HouseAge": round(np.random.uniform(1, 50), 2),        # House age
        "Population": int(np.random.uniform(100, 3000)),       # Population
        "Longitude": round(np.random.uniform(-124.35, -114.31), 5),
        "Latitude": round(np.random.uniform(32.54, 41.95), 5)
    }

# ----------------------------------
# 5. Loop to generate and send data
# ----------------------------------
print("🟢 Starting fake data generator. Press STOP to interrupt...\n")

while True:
    try:
        input_data = generate_fake_input()
        response = requests.post(API_URL, json=input_data)

        if response.status_code == 200:
            print(f"✅ Input: {input_data} => Prediction: {response.json()}")
        else:
            print(f"❌ Failed with status {response.status_code}: {response.text}")
        
        time.sleep(5)  # Sleep for 5 seconds

    except KeyboardInterrupt:
        print("\n🛑 Stopped by user.")
        break
    except Exception as e:
        print(f"❗ Error occurred: {e}")
        time.sleep(5)
# Out:
# 🟢 Starting fake data generator. Press STOP to interrupt...
#
# ✅ Input: {'MedInc': 7.59, 'HouseAge': 18.7, 'Population': 825, 'Longitude': -116.22694, 'Latitude': 39.93207} => Prediction: ['prediction:', 3.3741949029126186]
# ✅ Input: {'MedInc': 7.05, 'HouseAge': 20.67, 'Population': 2307, 'Longitude': -114.46434, 'Latitude': 34.83263} => Prediction: ['prediction:', 3.3741949029126186]
# ✅ Input: {'MedInc': 14.69, 'HouseAge': 4.1, 'Population': 1696, 'Longitude': -117.34786, 'Latitude': 40.17917} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 6.87, 'HouseAge': 47.89, 'Population': 2473, 'Longitude': -114.43658, 'Latitude': 36.25392} => Prediction: ['prediction:', 4.150307478260866]
# ✅ Input: {'MedInc': 11.22, 'HouseAge': 26.07, 'Population': 398, 'Longitude': -115.24546, 'Latitude': 39.74389} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 8.38, 'HouseAge': 15.69, 'Population': 1454, 'Longitude': -119.29675, 'Latitude': 39.97533} => Prediction: ['prediction:', 3.972031488095234]
# ✅ Input: {'MedInc': 5.94, 'HouseAge': 12.18, 'Population': 841, 'Longitude': -117.1617, 'Latitude': 40.82433} => Prediction: ['prediction:', 2.7965691666666666]
# ✅ Input: {'MedInc': 12.54, 'HouseAge': 3.21, 'Population': 1163, 'Longitude': -123.71272, 'Latitude': 40.1094} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 3.61, 'HouseAge': 27.8, 'Population': 1589, 'Longitude': -119.89275, 'Latitude': 40.60443} => Prediction: [1.4442132963988914, 'prediction:']
# ✅ Input: {'MedInc': 12.59, 'HouseAge': 43.93, 'Population': 2577, 'Longitude': -114.57475, 'Latitude': 36.55063} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 12.13, 'HouseAge': 40.24, 'Population': 1099, 'Longitude': -117.62126, 'Latitude': 34.4155} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 1.26, 'HouseAge': 35.4, 'Population': 904, 'Longitude': -120.629, 'Latitude': 40.98783} => Prediction: [1.052650311220312, 'prediction:']
# ✅ Input: {'MedInc': 12.27, 'HouseAge': 9.94, 'Population': 433, 'Longitude': -122.86779, 'Latitude': 34.59475} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 6.29, 'HouseAge': 23.7, 'Population': 1799, 'Longitude': -121.77761, 'Latitude': 39.56472} => Prediction: ['prediction:', 2.7965691666666666]
# ✅ Input: {'MedInc': 13.94, 'HouseAge': 13.09, 'Population': 2900, 'Longitude': -116.54491, 'Latitude': 40.34099} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 1.56, 'HouseAge': 48.67, 'Population': 1940, 'Longitude': -123.97502, 'Latitude': 39.55468} => Prediction: [1.0612313134328357, 'prediction:']
# ✅ Input: {'MedInc': 8.06, 'HouseAge': 4.81, 'Population': 2388, 'Longitude': -119.83351, 'Latitude': 36.38127} => Prediction: ['prediction:', 3.972031488095234]
# ✅ Input: {'MedInc': 6.34, 'HouseAge': 32.72, 'Population': 2372, 'Longitude': -118.99882, 'Latitude': 37.13908} => Prediction: ['prediction:', 3.6403393984962396]
# ✅ Input: {'MedInc': 1.04, 'HouseAge': 2.07, 'Population': 369, 'Longitude': -122.31681, 'Latitude': 39.8073} => Prediction: [1.0612313134328357, 'prediction:']
# ✅ Input: {'MedInc': 12.52, 'HouseAge': 20.48, 'Population': 289, 'Longitude': -118.4579, 'Latitude': 33.4781} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 13.84, 'HouseAge': 40.11, 'Population': 370, 'Longitude': -122.78305, 'Latitude': 39.22151} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 14.65, 'HouseAge': 23.58, 'Population': 2580, 'Longitude': -118.67915, 'Latitude': 36.26399} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 2.09, 'HouseAge': 22.76, 'Population': 2864, 'Longitude': -123.17035, 'Latitude': 33.10295} => Prediction: ['prediction:', 2.447144143835617]
# ✅ Input: {'MedInc': 13.96, 'HouseAge': 40.18, 'Population': 2756, 'Longitude': -120.84161, 'Latitude': 36.99271} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 5.95, 'HouseAge': 38.53, 'Population': 1657, 'Longitude': -115.40363, 'Latitude': 33.44161} => Prediction: ['prediction:', 3.6403393984962396]
# ✅ Input: {'MedInc': 11.35, 'HouseAge': 12.03, 'Population': 2922, 'Longitude': -120.69752, 'Latitude': 38.61626} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 10.99, 'HouseAge': 21.42, 'Population': 1281, 'Longitude': -117.53124, 'Latitude': 35.03918} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 5.53, 'HouseAge': 7.28, 'Population': 1254, 'Longitude': -119.70826, 'Latitude': 33.50152} => Prediction: ['prediction:', 2.2187636421725236]
# ✅ Input: {'MedInc': 8.25, 'HouseAge': 15.99, 'Population': 1180, 'Longitude': -121.26167, 'Latitude': 38.54889} => Prediction: ['prediction:', 3.972031488095234]
# ✅ Input: {'MedInc': 3.3, 'HouseAge': 10.24, 'Population': 400, 'Longitude': -122.18703, 'Latitude': 41.47297} => Prediction: [1.4442132963988914, 'prediction:']
# ✅ Input: {'MedInc': 8.23, 'HouseAge': 10.54, 'Population': 2370, 'Longitude': -120.13816, 'Latitude': 34.26843} => Prediction: ['prediction:', 3.972031488095234]
# ✅ Input: {'MedInc': 10.5, 'HouseAge': 25.63, 'Population': 673, 'Longitude': -121.99377, 'Latitude': 37.80275} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 8.27, 'HouseAge': 29.83, 'Population': 1287, 'Longitude': -123.06811, 'Latitude': 34.70215} => Prediction: ['prediction:', 4.778788739495791]
# ✅ Input: {'MedInc': 8.23, 'HouseAge': 32.86, 'Population': 1306, 'Longitude': -116.82982, 'Latitude': 32.65581} => Prediction: ['prediction:', 4.778788739495791]
# ✅ Input: {'MedInc': 13.82, 'HouseAge': 44.29, 'Population': 2959, 'Longitude': -122.48684, 'Latitude': 37.49821} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 2.53, 'HouseAge': 41.07, 'Population': 1730, 'Longitude': -119.82251, 'Latitude': 37.03588} => Prediction: [0.7225785674547989, 'prediction:']
# ✅ Input: {'MedInc': 10.24, 'HouseAge': 40.75, 'Population': 2277, 'Longitude': -120.87107, 'Latitude': 40.33748} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 7.52, 'HouseAge': 35.55, 'Population': 1571, 'Longitude': -123.04006, 'Latitude': 40.39027} => Prediction: ['prediction:', 3.6397148571428573]
# ✅ Input: {'MedInc': 5.54, 'HouseAge': 38.38, 'Population': 728, 'Longitude': -120.94148, 'Latitude': 39.89931} => Prediction: ['prediction:', 3.3870605936073046]
# ✅ Input: {'MedInc': 13.3, 'HouseAge': 32.69, 'Population': 1865, 'Longitude': -115.81801, 'Latitude': 37.3787} => Prediction: ['prediction:', 4.860650727272712]
# ✅ Input: {'MedInc': 7.22, 'HouseAge': 25.15, 'Population': 2625, 'Longitude': -114.96913, 'Latitude': 34.63811} => Prediction: ['prediction:', 3.3741949029126186]
#
# 🛑 Stopped by user.
